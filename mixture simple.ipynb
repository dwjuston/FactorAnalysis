# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm, lognorm

# %%
# https://www.geeksforgeeks.org/how-to-plot-normal-distribution-over-histogram-in-python/
    
data = np.random.normal(170, 10, 250)
  
# Fit a normal distribution to
# the data:
# mean and standard deviation
mu, std = norm.fit(data) 
  
# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k', linewidth=2)
title = "Fit Values: {:.2f} and {:.2f}".format(mu, std)
plt.title(title)
  
plt.show()

# %%
data = np.random.normal(0, 5, 500)
mu, std = norm.fit(data) 
  
# Plot the histogram.
plt.hist(data, bins='auto', density=True, alpha=0.6, color='b')
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k', linewidth=2)

# %%
data = np.random.normal(0, 5, 500)
mu, std = norm.fit(data) 
  
# Plot the histogram.
plt.hist(data, bins='auto', density=True, alpha=0.6, color='b')
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k', linewidth=2)

data_small = np.random.normal(0, 2, 500)
data_big = np.random.normal(0, 8, 500)
data_mixture = np.array(list(data_small) + list(data_big))
_ = plt.hist(data_mixture, bins='auto', density=True, alpha=0.6, color='r')
